# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 200px" src="https://raw.githubusercontent.com/raxlab/imt2200-data/main/media/logo.jpg">  IMT 2200 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Instituto de Ingeniería Matemática y Computacional**<br>
# **Semestre 2025-S2**<br>
# **Profesor:** Rodrigo A. Carrasco <br>

# %% [markdown]
# # <h1><center>Actividad 01: Herramientas Computacionales para Ciencia de Datos </center></h1>
#
# ## 1. Objetivos de la Actividad
#
# Esta Actividad tiene como objetivo probar el ambiente de programación de cada estudiante, la instalación de librerías de Python. El segundo objetivo es aprender a usar GitHub, a configurar su repositorio, y entregar la actividad.

# %% [markdown]
# ## 2. Módulos de Python
#
# ### 2.1 Importar módulos
#
# Se recomienda comenzar con la importación de módulos o librerías de funciones para distintos usos, o partes de una libreria
# Para facilitar la referencia a librerías en el resto del código, se acostumbra asignarles un alias. La sintaxis general a usar para importar un módulo es:
#
# ``import NOMBRE_MODULO as ALIAS_MODULO``
# o
# ``from NOMBRE_MODULO import FUNCION``

# %%
#Importación de librerías: importe las siguientes librerías, usando alias comunes: numpy, pandas, geopandas
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3. Ejercicio: Inspección de Datos del Censo 2017
# El código a continuación permite descargar, leer, hacer algunos cálculos básicos y visualizar los datos de población del censo chileno de 2017 para la región metropolitana.
# En este notebook, ud. sólo debe ejecutar las celdas de código a continuación, hasta generar una figura con la distribución de población total por manzana censal en la RM. Como demostración de la ejecución exitosa del código, debe subir este notebook y la figura final a su repositorio de Github.

# %%
#Leer archivo enun DataFrame
dat=pd.read_csv('Censo2017_Manzanas.csv',delimiter=';')

#Visualizar las primeras lineas

#NOTA: Adicionalmente, como una iniciativa mia, decidi destacar de color rojo las celdas "PERSONAS", "HOMBRES" y "MUJERES"
#de la fila que tenia la mayor cantidad de habitantes. Hice lo mismo, pero con color celeste, las celdas de la fila con menor población.
dat.head().style.highlight_max(subset=dat.columns[9:12], color="salmon").highlight_min(subset=dat.columns[9:12], color="lightblue")
# Out:
# <style type="text/css">
# #T_7f686_row0_col9, #T_7f686_row0_col10, #T_7f686_row0_col11 {
#   background-color: lightblue;
# }
# #T_7f686_row1_col9, #T_7f686_row1_col10, #T_7f686_row1_col11 {
#   background-color: salmon;
# }
# </style>
# <table id="T_7f686">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f686_level0_col0" class="col_heading level0 col0" >REGION</th>
#       <th id="T_7f686_level0_col1" class="col_heading level0 col1" >PROVINCIA</th>
#       <th id="T_7f686_level0_col2" class="col_heading level0 col2" >COMUNA</th>
#       <th id="T_7f686_level0_col3" class="col_heading level0 col3" >DC</th>
#       <th id="T_7f686_level0_col4" class="col_heading level0 col4" >AREA</th>
#       <th id="T_7f686_level0_col5" class="col_heading level0 col5" >ZC_LOC</th>
#       <th id="T_7f686_level0_col6" class="col_heading level0 col6" >MZ_ENT</th>
#       <th id="T_7f686_level0_col7" class="col_heading level0 col7" >ID_ZONA_LOC</th>
#       <th id="T_7f686_level0_col8" class="col_heading level0 col8" >ID_MANZENT</th>
#       <th id="T_7f686_level0_col9" class="col_heading level0 col9" >PERSONAS</th>
#       <th id="T_7f686_level0_col10" class="col_heading level0 col10" >HOMBRES</th>
#       <th id="T_7f686_level0_col11" class="col_heading level0 col11" >MUJERES</th>
#       <th id="T_7f686_level0_col12" class="col_heading level0 col12" >EDAD_0A5</th>
#       <th id="T_7f686_level0_col13" class="col_heading level0 col13" >EDAD_6A14</th>
#       <th id="T_7f686_level0_col14" class="col_heading level0 col14" >EDAD_15A64</th>
#       <th id="T_7f686_level0_col15" class="col_heading level0 col15" >EDAD_65YMAS</th>
#       <th id="T_7f686_level0_col16" class="col_heading level0 col16" >INMIGRANTES</th>
#       <th id="T_7f686_level0_col17" class="col_heading level0 col17" >PUEBLO</th>
#       <th id="T_7f686_level0_col18" class="col_heading level0 col18" >VIV_PART</th>
#       <th id="T_7f686_level0_col19" class="col_heading level0 col19" >VIV_COL</th>
#       <th id="T_7f686_level0_col20" class="col_heading level0 col20" >VPOMP</th>
#       <th id="T_7f686_level0_col21" class="col_heading level0 col21" >TOTAL_VIV</th>
#       <th id="T_7f686_level0_col22" class="col_heading level0 col22" >CANT_HOG</th>
#       <th id="T_7f686_level0_col23" class="col_heading level0 col23" >P01_1</th>
#       <th id="T_7f686_level0_col24" class="col_heading level0 col24" >P01_2</th>
#       <th id="T_7f686_level0_col25" class="col_heading level0 col25" >P01_3</th>
#       <th id="T_7f686_level0_col26" class="col_heading level0 col26" >P01_4</th>
#       <th id="T_7f686_level0_col27" class="col_heading level0 col27" >P01_5</th>
#       <th id="T_7f686_level0_col28" class="col_heading level0 col28" >P01_6</th>
#       <th id="T_7f686_level0_col29" class="col_heading level0 col29" >P01_7</th>
#       <th id="T_7f686_level0_col30" class="col_heading level0 col30" >P03A_1</th>
#       <th id="T_7f686_level0_col31" class="col_heading level0 col31" >P03A_2</th>
#       <th id="T_7f686_level0_col32" class="col_heading level0 col32" >P03A_3</th>
#       <th id="T_7f686_level0_col33" class="col_heading level0 col33" >P03A_4</th>
#       <th id="T_7f686_level0_col34" class="col_heading level0 col34" >P03A_5</th>
#       <th id="T_7f686_level0_col35" class="col_heading level0 col35" >P03A_6</th>
#       <th id="T_7f686_level0_col36" class="col_heading level0 col36" >P03B_1</th>
#       <th id="T_7f686_level0_col37" class="col_heading level0 col37" >P03B_2</th>
#       <th id="T_7f686_level0_col38" class="col_heading level0 col38" >P03B_3</th>
#       <th id="T_7f686_level0_col39" class="col_heading level0 col39" >P03B_4</th>
#       <th id="T_7f686_level0_col40" class="col_heading level0 col40" >P03B_5</th>
#       <th id="T_7f686_level0_col41" class="col_heading level0 col41" >P03B_6</th>
#       <th id="T_7f686_level0_col42" class="col_heading level0 col42" >P03B_7</th>
#       <th id="T_7f686_level0_col43" class="col_heading level0 col43" >P03C_1</th>
#       <th id="T_7f686_level0_col44" class="col_heading level0 col44" >P03C_2</th>
#       <th id="T_7f686_level0_col45" class="col_heading level0 col45" >P03C_3</th>
#       <th id="T_7f686_level0_col46" class="col_heading level0 col46" >P03C_4</th>
#       <th id="T_7f686_level0_col47" class="col_heading level0 col47" >P03C_5</th>
#       <th id="T_7f686_level0_col48" class="col_heading level0 col48" >MATACEP</th>
#       <th id="T_7f686_level0_col49" class="col_heading level0 col49" >MATREC</th>
#       <th id="T_7f686_level0_col50" class="col_heading level0 col50" >MATIRREC</th>
#       <th id="T_7f686_level0_col51" class="col_heading level0 col51" >P05_1</th>
#       <th id="T_7f686_level0_col52" class="col_heading level0 col52" >P05_2</th>
#       <th id="T_7f686_level0_col53" class="col_heading level0 col53" >P05_3</th>
#       <th id="T_7f686_level0_col54" class="col_heading level0 col54" >P05_4</th>
#       <th id="T_7f686_level0_col55" class="col_heading level0 col55" >REGION_15R</th>
#       <th id="T_7f686_level0_col56" class="col_heading level0 col56" >PROVINCIA_15R</th>
#       <th id="T_7f686_level0_col57" class="col_heading level0 col57" >COMUNA_15R</th>
#       <th id="T_7f686_level0_col58" class="col_heading level0 col58" >ID_MANZENT_15R</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f686_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f686_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7f686_row0_col1" class="data row0 col1" >11</td>
#       <td id="T_7f686_row0_col2" class="data row0 col2" >1101</td>
#       <td id="T_7f686_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_7f686_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_7f686_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_7f686_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_7f686_row0_col7" class="data row0 col7" >7849</td>
#       <td id="T_7f686_row0_col8" class="data row0 col8" >1101011001001</td>
#       <td id="T_7f686_row0_col9" class="data row0 col9" >15</td>
#       <td id="T_7f686_row0_col10" class="data row0 col10" >*</td>
#       <td id="T_7f686_row0_col11" class="data row0 col11" >*</td>
#       <td id="T_7f686_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_7f686_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_7f686_row0_col14" class="data row0 col14" >15</td>
#       <td id="T_7f686_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_7f686_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_7f686_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_7f686_row0_col18" class="data row0 col18" >1</td>
#       <td id="T_7f686_row0_col19" class="data row0 col19" >2</td>
#       <td id="T_7f686_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_7f686_row0_col21" class="data row0 col21" >3</td>
#       <td id="T_7f686_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_7f686_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_7f686_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_7f686_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_7f686_row0_col26" class="data row0 col26" >0</td>
#       <td id="T_7f686_row0_col27" class="data row0 col27" >0</td>
#       <td id="T_7f686_row0_col28" class="data row0 col28" >0</td>
#       <td id="T_7f686_row0_col29" class="data row0 col29" >1</td>
#       <td id="T_7f686_row0_col30" class="data row0 col30" >0</td>
#       <td id="T_7f686_row0_col31" class="data row0 col31" >0</td>
#       <td id="T_7f686_row0_col32" class="data row0 col32" >0</td>
#       <td id="T_7f686_row0_col33" class="data row0 col33" >0</td>
#       <td id="T_7f686_row0_col34" class="data row0 col34" >0</td>
#       <td id="T_7f686_row0_col35" class="data row0 col35" >0</td>
#       <td id="T_7f686_row0_col36" class="data row0 col36" >0</td>
#       <td id="T_7f686_row0_col37" class="data row0 col37" >0</td>
#       <td id="T_7f686_row0_col38" class="data row0 col38" >0</td>
#       <td id="T_7f686_row0_col39" class="data row0 col39" >0</td>
#       <td id="T_7f686_row0_col40" class="data row0 col40" >0</td>

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180499 entries, 0 to 180498
# Data columns (total 59 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   REGION          180499 non-null  int64
#  1   PROVINCIA       180499 non-null  int64
#  2   COMUNA          180499 non-null  int64
#  3   DC              180499 non-null  int64
#  4   AREA            180499 non-null  int64
#  5   ZC_LOC          180499 non-null  int64
#  6   MZ_ENT          180499 non-null  int64
#  7   ID_ZONA_LOC     180499 non-null  int64
#  8   ID_MANZENT      180499 non-null  int64
#  9   PERSONAS        180499 non-null  int64
#  10  HOMBRES         180499 non-null  object
#  11  MUJERES         180499 non-null  object
#  12  EDAD_0A5        180499 non-null  object
#  13  EDAD_6A14       180499 non-null  object
#  14  EDAD_15A64      180499 non-null  object
#  15  EDAD_65YMAS     180499 non-null  object
#  16  INMIGRANTES     180499 non-null  object
#  17  PUEBLO          180499 non-null  object
#  18  VIV_PART        180499 non-null  int64
#  19  VIV_COL         180499 non-null  int64
#  20  VPOMP           180499 non-null  int64
#  21  TOTAL_VIV       180499 non-null  int64
#  22  CANT_HOG        180499 non-null  int64
#  23  P01_1           180499 non-null  int64
#  24  P01_2           180499 non-null  int64
#  25  P01_3           180499 non-null  int64
#  26  P01_4           180499 non-null  int64
#  27  P01_5           180499 non-null  int64
#  28  P01_6           180499 non-null  int64
#  29  P01_7           180499 non-null  int64
#  30  P03A_1          180499 non-null  int64
#  31  P03A_2          180499 non-null  int64
#  32  P03A_3          180499 non-null  int64
#  33  P03A_4          180499 non-null  int64
#  34  P03A_5          180499 non-null  int64
#  35  P03A_6          180499 non-null  int64
#  36  P03B_1          180499 non-null  int64
#  37  P03B_2          180499 non-null  int64
#  38  P03B_3          180499 non-null  int64
#  39  P03B_4          180499 non-null  int64
#  40  P03B_5          180499 non-null  int64
#  41  P03B_6          180499 non-null  int64
#  42  P03B_7          180499 non-null  int64
#  43  P03C_1          180499 non-null  int64
#  44  P03C_2          180499 non-null  int64
#  45  P03C_3          180499 non-null  int64
#  46  P03C_4          180499 non-null  int64
#  47  P03C_5          180499 non-null  int64
#  48  MATACEP         180499 non-null  int64
#  49  MATREC          180499 non-null  int64
#  50  MATIRREC        180499 non-null  int64
#  51  P05_1           180499 non-null  int64
#  52  P05_2           180499 non-null  int64
#  53  P05_3           180499 non-null  int64
#  54  P05_4           180499 non-null  int64
#  55  REGION_15R      180499 non-null  int64
#  56  PROVINCIA_15R   180499 non-null  int64
#  57  COMUNA_15R      180499 non-null  int64
#  58  ID_MANZENT_15R  180499 non-null  int64
# dtypes: int64(51), object(8)
# memory usage: 81.2+ MB

# %% [markdown]
# ### Pregunta: ¿Cuál era la población total de Chile en 2017?
#
# Para responderla podemos hacer un cálculo sencillo y sumar todos los datos de la columna `PERSONAS`:

# %%
#Total de población
total_pop=dat['PERSONAS'].sum()
print(f'Población total en 2017: {total_pop}')
# Out:
# Población total en 2017: 17574003

# %% [markdown]
# También podemos usar algunas funciones más avanzadas de `pandas`para analizar la distribución de personas por región y edad:

# %%
#Distribución por edad y género
cols=['EDAD_0A5','EDAD_6A14','EDAD_15A64','EDAD_65YMAS']
for col in cols:
    dat[col]=dat[col].replace('*',0).astype(float)
    
pv=pd.pivot_table(dat, index='REGION', values=cols, aggfunc='sum', margins=False)

#NOTA: Al igual que en la gráfica anterior, decidi destacar de color rojo las celdas de la región con mayor cantidad de personas en un determinado
#rango de edad, hice lo mismo, pero con color celeste para las celdas de la región con menor cantidad de personas en cierto rango de edades.
#Adicionalmente elimine el decimal final ".0" de cada dato de numeros.
pv.style.format("{:.0f}").highlight_max(color="salmon").highlight_min(color="lightblue")
# Out:
# <style type="text/css">
# #T_45c24_row10_col0, #T_45c24_row10_col1, #T_45c24_row10_col2, #T_45c24_row10_col3 {
#   background-color: lightblue;
# }
# #T_45c24_row12_col0, #T_45c24_row12_col1, #T_45c24_row12_col2, #T_45c24_row12_col3 {
#   background-color: salmon;
# }
# </style>
# <table id="T_45c24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45c24_level0_col0" class="col_heading level0 col0" >EDAD_0A5</th>
#       <th id="T_45c24_level0_col1" class="col_heading level0 col1" >EDAD_15A64</th>
#       <th id="T_45c24_level0_col2" class="col_heading level0 col2" >EDAD_65YMAS</th>
#       <th id="T_45c24_level0_col3" class="col_heading level0 col3" >EDAD_6A14</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >REGION</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45c24_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_45c24_row0_col0" class="data row0 col0" >27089</td>
#       <td id="T_45c24_row0_col1" class="data row0 col1" >225991</td>
#       <td id="T_45c24_row0_col2" class="data row0 col2" >22784</td>
#       <td id="T_45c24_row0_col3" class="data row0 col3" >42860</td>
#     </tr>
#     <tr>
#       <th id="T_45c24_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_45c24_row1_col0" class="data row1 col0" >40763</td>
#       <td id="T_45c24_row1_col1" class="data row1 col1" >427746</td>
#       <td id="T_45c24_row1_col2" class="data row1 col2" >40299</td>
#       <td id="T_45c24_row1_col3" class="data row1 col3" >70497</td>
#     </tr>
#     <tr>
#       <th id="T_45c24_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_45c24_row2_col0" class="data row2 col0" >18862</td>
#       <td id="T_45c24_row2_col1" class="data row2 col1" >188979</td>
#       <td id="T_45c24_row2_col2" class="data row2 col2" >23711</td>
#       <td id="T_45c24_row2_col3" class="data row2 col3" >33304</td>
#     </tr>
#     <tr>
#       <th id="T_45c24_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_45c24_row3_col0" class="data row3 col0" >49130</td>
#       <td id="T_45c24_row3_col1" class="data row3 col1" >498186</td>
#       <td id="T_45c24_row3_col2" class="data row3 col2" >77212</td>
#       <td id="T_45c24_row3_col3" class="data row3 col3" >83390</td>
#     </tr>
#     <tr>
#       <th id="T_45c24_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_45c24_row4_col0" class="data row4 col0" >110371</td>
#       <td id="T_45c24_row4_col1" class="data row4 col1" >1212273</td>
#       <td id="T_45c24_row4_col2" class="data row4 col2" >222900</td>
#       <td id="T_45c24_row4_col3" class="data row4 col3" >176235</td>
#     </tr>
#     <tr>
#       <th id="T_45c24_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_45c24_row5_col0" class="data row5 col0" >58426</td>
#       <td id="T_45c24_row5_col1" class="data row5 col1" >609723</td>
#       <td id="T_45c24_row5_col2" class="data row5 col2" >96677</td>
#       <td id="T_45c24_row5_col3" class="data row5 col3" >100364</td>
#     </tr>
#     <tr>
#       <th id="T_45c24_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_45c24_row6_col0" class="data row6 col0" >62106</td>
#       <td id="T_45c24_row6_col1" class="data row6 col1" >695161</td>
#       <td id="T_45c24_row6_col2" class="data row6 col2" >111206</td>
#       <td id="T_45c24_row6_col3" class="data row6 col3" >108436</td>
#     </tr>
#     <tr>
#       <th id="T_45c24_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_45c24_row7_col0" class="data row7 col0" >98184</td>
#       <td id="T_45c24_row7_col1" class="data row7 col1" >1049723</td>
#       <td id="T_45c24_row7_col2" class="data row7 col2" >164977</td>
#       <td id="T_45c24_row7_col3" class="data row7 col3" >166678</td>
#     </tr>
#     <tr>
#       <th id="T_45c24_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_45c24_row8_col0" class="data row8 col0" >57165</td>
#       <td id="T_45c24_row8_col1" class="data row8 col1" >629746</td>
#       <td id="T_45c24_row8_col2" class="data row8 col2" >103612</td>
#       <td id="T_45c24_row8_col3" class="data row8 col3" >99561</td>
#     </tr>
#     <tr>
#       <th id="T_45c24_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_45c24_row9_col0" class="data row9 col0" >47403</td>
#       <td id="T_45c24_row9_col1" class="data row9 col1" >555544</td>
#       <td id="T_45c24_row9_col2" class="data row9 col2" >78907</td>
#       <td id="T_45c24_row9_col3" class="data row9 col3" >90394</td>
#     </tr>
#     <tr>
#       <th id="T_45c24_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_45c24_row10_col0" class="data row10 col0" >5684</td>
#       <td id="T_45c24_row10_col1" class="data row10 col1" >67980</td>
#       <td id="T_45c24_row10_col2" class="data row10 col2" >7017</td>
#       <td id="T_45c24_row10_col3" class="data row10 col3" >12061</td>
#     </tr>
#     <tr>
#       <th id="T_45c24_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_45c24_row11_col0" class="data row11 col0" >8029</td>
#       <td id="T_45c24_row11_col1" class="data row11 col1" >112754</td>
#       <td id="T_45c24_row11_col2" class="data row11 col2" >16636</td>
#       <td id="T_45c24_row11_col3" class="data row11 col3" >15331</td>
#     </tr>
#     <tr>
#       <th id="T_45c24_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_45c24_row12_col0" class="data row12 col0" >498778</td>
#       <td id="T_45c24_row12_col1" class="data row12 col1" >4953736</td>
#       <td id="T_45c24_row12_col2" class="data row12 col2" >731246</td>
#       <td id="T_45c24_row12_col3" class="data row12 col3" >759246</td>
#     </tr>
#     <tr>
#       <th id="T_45c24_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_45c24_row13_col0" class="data row13 col0" >21771</td>
#       <td id="T_45c24_row13_col1" class="data row13 col1" >255977</td>
#       <td id="T_45c24_row13_col2" class="data row13 col2" >41598</td>
#       <td id="T_45c24_row13_col3" class="data row13 col3" >39097</td>
#     </tr>
#     <tr>
#       <th id="T_45c24_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_45c24_row14_col0" class="data row14 col0" >16207</td>
#       <td id="T_45c24_row14_col1" class="data row14 col1" >151468</td>
#       <td id="T_45c24_row14_col2" class="data row14 col2" >22560</td>
#       <td id="T_45c24_row14_col3" class="data row14 col3" >26333</td>
#     </tr>
#     <tr>
#       <th id="T_45c24_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_45c24_row15_col0" class="data row15 col0" >26815</td>
#       <td id="T_45c24_row15_col1" class="data row15 col1" >317668</td>
#       <td id="T_45c24_row15_col2" class="data row15 col2" >56137</td>
#       <td id="T_45c24_row15_col3" class="data row15 col3" >48137</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <u>**Analisis**</u>: De acuerdo a la tabla anterior, podemos ver que las celdas destacadas con color rojo corresponden a la región con la mayor cantidad de habitantes, la cual es la numero 13 (Región Metropolitana), y la que tiene la menor cantidad de habitantes esta destacada con color celeste y corresponde a la número 11 (Región de Aysen).

# %% [markdown]
# Y podemos graficar la cantidad por región:

# %%
fig = plt.figure(figsize=(11,3))
ax = fig.add_subplot(111)
ax.set_ylabel('Número de personas')
fig.suptitle('Distribución de población por Edad y Región (Chile, Censo 2017)')
pv.plot(kind='bar', ax =ax);

# %% [markdown]
# Como podemos apreciar en la gráfica de barras, se cumple que la región numero 13 tiene la mayor cantidad de habitantes debido a que presenta las barras con mayor altura. Y la región con menor cantidad de habitantes es la 11, como podemos ver, el largo de sus barras es casi inexistente. Por lo cual tambien podemos inferir que la información de la tabla y la gráfica coinciden en su totalidad.

# %% [markdown]
# ## 4. Creación de un Mapa con información del Censo
#
# A continuación usaremos librerías de geopandas para conectar un mapa de la Región Metropolitana con datos del Censo de 2017.

# %%
#Leer datos censales
manz=gpd.read_file('R13/MANZANA_IND_C17.shp')
com=gpd.read_file('R13/COMUNA_C17.shp')

# %% [markdown]
# Geopandas permite graficar archivos de mapas de múltiples formas. Para más información pueden revisar el siguiente enlace: https://geopandas.org/en/stable/docs/user_guide/mapping.html

# %%
#Junto con imprimir el mapa de Santiago, decidi cambiar los bordes de las comunas a blanco, y el "relleno" lo decidi cambiar a verde
com.plot(edgecolor="white", facecolor="darkgreen")
# Out:
# <Axes: >

# %%
manz.head()
# Out:
#   REGION                        NOM_REGION PROVINCIA NOM_PROVIN COMUNA  \
# 0     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 1     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 2     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 3     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 4     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
#
#   NOM_COMUNA  DISTRITO  LOC_ZON  ENT_MAN  CATEGORIA NOM_CATEGO  \
# 0   SANTIAGO         7        1        2          1         CD
# 1   SANTIAGO         8        1        2          1         CD
# 2   SANTIAGO         7        1        3          1         CD
# 3   SANTIAGO         7        1        4          1         CD
# 4   SANTIAGO         7        1        8          1         CD
#
#         MANZENT_I  TOTAL_PERS  TOTAL_VIVI  SHAPE_Leng    SHAPE_Area  \
# 0  13101071001002         764         287    0.005560  1.354544e-06
# 1  13101081001002        1307         509    0.006557  2.630421e-06
# 2  13101071001003          64          17    0.003859  5.979189e-07
# 3  13101071001004          52          21    0.004683  1.265246e-06
# 4  13101071001008          67          14    0.003491  7.452444e-07
#
#                                             geometry
# 0  POLYGON ((-70.67695 -33.42691, -70.67685 -33.4...
# 1  POLYGON ((-70.67362 -33.42898, -70.67517 -33.4...
# 2  POLYGON ((-70.67812 -33.42803, -70.67813 -33.4...
# 3  POLYGON ((-70.68043 -33.42897, -70.68046 -33.4...
# 4  POLYGON ((-70.67805 -33.42921, -70.67858 -33.4...

# %% [markdown]
# El siguiente código conecta el mapa de la Región Metropolitana con la población por manzana del Censo 2017. Edite el código para que la figura tenga su nombre en el Titulo

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as colors

#Crear figura y ejes
fig=plt.figure(figsize=(13,13))
ax=fig.add_subplot(111)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

# cantidad de personas por manzana
Z=manz['TOTAL_PERS']
manz.plot(ax=ax, column='TOTAL_PERS', cmap='Reds', legend=True, vmin=0, vmax=1000)

com_projected = com.to_crs(epsg=3857)
com_projected.boundary.plot(ax=ax, lw=0.2, color='k')

xlim=[-70.9,-70.4]
ylim=[-33.7,-33.2]
for x, y, label in zip(com_projected.geometry.centroid.x, com_projected.geometry.centroid.y, com_projected.NOM_COMUNA):
    if xlim[0]<x<xlim[1] and ylim[0]<y<ylim[1]:
        ax.text(x, y, label, fontsize = 10)
        
ax.set_xlim(xlim)
ax.set_ylim(ylim);

## Reemplace 'XXX' por su apellido
ax.set_title('RM - Población total por manzana - Censo 2017 - Ejecutado por Espinoza',fontsize=10)

## Reemplace 'XXX' por su apellido en el nombre del archivo de salida 
fig.savefig('PoblacionRM_C2017_Espinoza.jpg')

# %% [markdown]
# ## 5. Cierre de la Actividad 01: Repositorio presonal
#
# Para terminar la Actividad 01, deben hacer los siguientes pasos:
# - Crear un repositorio en su cuenta personal con el nombre ``IMT2200-<NOMBRE>-<APELLIDO>`` y clonar en su computador.
# - Crear una carpeta adentro llamada "Actividad 01" y copiar adentro el contenido de la carpeta "Actividad 01" del repositorio del curso.
# - Actualizar el repositorio agregando el Notebook de Jupyter y la imagen con el Mapa con su nombre.
# - Editar el archivo ``README.md`` para describir su repositorio.
# - Entregar en el módulo ``Actividad 1`` en Canvas la URL de su repositorio para corrección.
